# %%
! pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\avina\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\avina\anaconda3\lib\site-packages (from beautifulsoup4) (2.2.1)

# %%
! pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\avina\anaconda3\lib\site-packages (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\avina\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\avina\anaconda3\lib\site-packages (from requests) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\avina\anaconda3\lib\site-packages (from requests) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\avina\anaconda3\lib\site-packages (from requests) (2.0.4)

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests

# %%
try:
        
    page=requests.get('https://www.cricbuzz.com/')                            
    
except Exception as e:                                   
    error_type, error_obj, error_info = sys.exc_info()      
    print ('ERROR FOR LINK:',url)                          
    print (error_type, 'Line:', error_info.tb_lineno)     
                                                 
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta charset="utf-8"/><script>var is_mobile = /symbian|tizen|midp|uc(web|browser)|MSIE (5.0|6.0|7.0|8.0)|tablet/i.test(navigator.userAgent);	if(is_mobile && window.location.hostname != "www1.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";</script><style>body{background:#E3E6E3; font-family: helvetica,"Segoe UI",Arial,sans-serif;color:#222;font-size:14px; line-height: 1.5; margin:0;}	body, .cb-comm-pg, .cb-hm-mid {min-height:1000px}	.container{width:980px;margin:0 auto;}	.page{max-width: 980px;margin: 0 auto;position: relative;}	.cb-col-8 {width:8%;}	.cb-col-10 {width:10%;}	.cb-col-14 {width:14%;}	.cb-col-16 {width:16%;}	.cb-col-20 {width:20%;}	.cb-col-25 {width:25%;}	.cb-col-27 {width:27%;}	.cb-col-30 {width:30%;}	.cb-col-33 {width:33%;}	.cb-col-40 {width:40%;}	.cb-col-46 {width:46%;}	.cb-col-47 {width:47%;}	.cb-col-50 {width:50%;}	.cb-col-60 {width:60%;}	.cb-col-65 {width:65%;}	.cb-col-66 {width:66%;}	.cb-col-67 {width:67%;}	.cb-col-73 {width:73%;}	.cb-col-75 {width:75%;}	.cb-col-70 {width:70%;}	.cb-col-84 {width:84%;}	.cb-col-80 {width:80%;}	.cb-col-90{width:90%;}	.cb-col-100 {width:100%;}	.cb-col {display: inline-block;box-sizing: border-box;float: left; min-height: 1px;}	h1 {font-size: 36px;line-height: 42px; margin:0;}	h2 {font-size: 24px; margin:0; line-height: 30px;}	h3 {font-size: 18px;line-height: 24px; margin:0; }	h4 {font-size: 16px; margin:0; }	h5 {font-size: 14px; margin: 0;}	.cb-font-18 {font-size:18px;}	img{border-radius: 4px;}	a {text-decoration: none; color:#222;}	a, a:hover, a:active, a:focus {outline: medium none;}	.text-center {text-align: center;}	.cb-nws-lft-col{padding:15px 20px;}	.cb-nws-dtl-lft-col {padding: 10px 30px 0 30px;border-right: 1px solid #ecebeb ;}	.cb-nws-lst-rt{padding-left: 10px;}	.cb-srs-lst-itm {padding: 10px 0;}	.cb-lst-itm-sm{padding:10px 0 5px;}	.cb-scrd-lft-col{padding:15px 10px;} .cb-col-rt{padding: 10px;}	.text-white{color: #fff;}	.cb-scrd-hdr-rw, .cb-nav-pill-1.active {background: #028062 ;color: #fff;}	.cb-nav{position:relative; height:48px;background: #009270;}	.cb-hm-mnu-itm{padding: 16px 6px 11px; color:#fff; display:inline-block;}	.cb-hm-text{padding:10px 18px 10px 20px;}	.cb-hm-rght{padding: 15px;}	.cb-subnav .cb-sub-navigation {display: none; position: absolute;}	.cb-mat-mnu{background:#4a4a4a; width:980px; font-size: 0;}	.cb-mat-mnu-itm{font-size:12px; color:#fff; padding:10px; cursor: pointer; display:inline-block; max-width: 140px;}	.cb-mat-mnu-ttl{background: #333; padding: 10px 20px;}	.cb-mat-mnu-wrp{margin-bottom: 10px;}	.cb-ovr-flo{overflow: hidden; white-space: nowrap; text-overflow: ellipsis;}	.cb-mat-mnu-all{text-align: center; float: right; width:60px;}	.cb-nav-main{border-bottom:1px solid #e3e6e3;padding:0 0 5px 20px;}	.cb-nav-bar{padding-top:10px;clear:both;}	.cb-lst-itm, .cb-bg-white{background: #fff;}	.cb-nav-tab.active, .cb-nav-tab-hm.active{ font-weight: bold; color: #028062;}	.cb-nav-tab.active {border-bottom: 3px solid #028062; line-height: 24px; }	.cb-nav-tab-hm.active{ border-bottom:2px solid #028062; line-height: 22px;}	.cb-nav-tab{margin-right:20px;padding-bottom:6px;}	.cb-nav-tab-hm{margin-right:15px;padding-bottom:6px;}	.cb-nav-hdr{padding-top:15px}	.cb-nav-subhdr{padding:5px 0 10px 0;}	.cb-lv-scr-mtch-hdr{line-height: 21px;font-size: 16px;}	.disp-none{display:none;}	.disp-blck{display:block;}	.cb-font-24{font-size: 24px;}	.line-ht30{line-height: 30px;}	.line-ht24{line-height: 24px;}	.cb-hm-scg-blk{background: #fff; margin-bottom: 5px; height:90px;}	.mrgn-btm-5{margin-bottom : 5px;}	#scagTabContent .show{display: block; visibility: visible;}	#scagTabContent .hide{display: none; visibility: hidden;}	[ng\:cloak], [ng-cloak], [data-ng-cloak], [x-ng-cloak], .ng-cloak, .x-ng-cloak { display: none !important;}	.cb-hm-lft{margin-bottom:5px;padding:0 15px;}	.cb-hm-lft-hdr{margin:0; padding:15px 15px 0; color: #009270;} .cb-hm-mid {border-left: 5px solid #e3e6e3 ;border-rig ...
# .cb-user-itm{position:absolute; top:0; right:5px}</style> </div> </div> <div class="cb-user-itm cb-subnav"> <a href="/premium-subscription/user/account-info" id="cb-plus-user-icon"><span class="cb-plus-ico cb-user-icon"></span></a> <nav class="cb-sub-navigation" id="cb-plus-dropdown" style="right:0px;"> <a class="cb-subnav-item" href="/premium-subscription/user/account-info" target="_self" title="My Account">My Account</a> <a class="cb-subnav-item" ng-click="sign_out_user(false)" target="_self" title="Sign Out">Sign Out</a></nav> </div></nav><style>.cb-text-link{color:#1866db;}
# .cb-plus-menu-button{padding: 8px 14px; background: #fff; border-radius: 18px; border: 0;}
# .cb-plus-menu-button:hover,.cb-plus-menu-button:focus, .cb-plus-menu-button:active{background: #fff;}</style></div></header><div class="page"><div id="fb-root"></div><div class="container" id="page-wrapper" style="display:inline-block;"><div class="ad-unit shosh-embed" id="shosh" style="height:0; width:980px; text-align:center;"></div><span class="ad-unit" id="skin_left" style="overflow:hidden; position:fixed;top:0;left:calc(50% - 635px);margin-right:3px;z-index:-99;"></span><div class="html-refresh" disable-first-load="true" timeout="300000" url="/api/html/matches-menu"><div class="cb-col cb-col-100 mrgn-btm-5"><nav class="cb-mat-mnu" ng-init="direction='up'"><a class="cb-mat-mnu-itm cb-ovr-flo cb-mat-mnu-ttl" href="/cricket-match/live-scores" id="live-scores-link" target="_self" title="">MATCHES</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/46181/pbks-vs-rcb-60th-match-indian-premier-league-2022" target="_self" title="Punjab Kings v Royal Challengers Bangalore, 60th Match - PBKS Won">PBKS vs RCB - PBKS Won</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/46186/kkr-vs-srh-61st-match-indian-premier-league-2022" target="_self" title="Kolkata Knight Riders v Sunrisers Hyderabad, 61st Match - Preview">KKR vs SRH - Preview</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/44681/leic-vs-sus-county-div-2-county-championship-division-two-2022" target="_self" title="Leicestershire v Sussex, County Div 2 - Stumps">LEIC vs SUS - Stumps</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/44346/sur-vs-kent-county-div-1-county-championship-division-one-2022" target="_self" title="Surrey v Kent, County Div 1 - Stumps">SUR vs KENT - Stumps</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/44676/dur-vs-glam-county-div-2-county-championship-division-two-2022" target="_self" title="Durham v Glamorgan, County Div 2 - Stumps">DUR vs GLAM - Stumps</a><span ng-click="(direction=='up')?direction = 'down' : direction = 'up'"><a class="cb-mat-mnu-itm cb-mat-mnu-all" id="match-dropdown" ng-class="{true:'cb-mat-mnu-cls'}[direction=='down']"><span ng-bind="(direction=='up') ? 'ALL': 'CLOSE'"></span><span ng-class="(direction=='up') ? 'cb-caret-down' : 'cb-caret-up'"></span></a></span></nav><div id="matchmenu"><div class="cb-mm-wrp {{direction}}"><div class="cb-scg-drp-dwn cb-col cb-col-100 cb-mnu-{{direction}}"><nav class="nav cb-mm-nvtb" ng-init="option= 'all'"><a class="cb-nav-pill-2 {{(option=='all')?'active':''}}" ng-click="option='all'" style="margin-right: 20px;">All</a><a class="cb-nav-pill-2 {{(option=='live')?'active':''}}" ng-click="option='live'" style="margin-right: 20px;">Live Now</a><a class="cb-nav-pill-2 {{(option=='today')?'active':''}}" ng-click="option='today'" style="margin-right: 20px;">Today</a></nav><style>.cb-nt-{{option}}{opacity:0.4!important;}</style><ul class="cb-scg-drp-dwn-ul"><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-mm-typ">INTERNATIONAL</div><div class="cb-scg-srs-nm">Bangladesh v Sri Lanka, 2022</div><div class="cb-mtch-all cb-nt-live cb-nt-today"><a href="/live-cricket-scores/46611/ban-vs-sl-1st-test-bangladesh-v-sri-lanka-2022" target="_self" title="Bangladesh v Sri Lanka, 1st Test - Upcoming"><span class="cb-mm-mtch-tm">Bangladesh vs Sri Lanka</span><span class="cb-mm-liv-tag"></span></a><div class="cb-mm-mtch-nm">1st Test</div></div></div></li><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-scg-srs-nm">Valletta Cup 2022</div><div class="cb-mtch-all cb-nt-live cb-nt-today"><a href="/live-cricket-scores/47780/malta-vs-cze-7th-match-valletta-cup-2022" target="_self" title="Malta v Czech Republic, 7th Match - MALTA Won"><span class="cb-mm-mtch-tm">Malta vs Czech Republic</span><span class="cb-mm-liv-tag"></span></a><div class="cb-mm-mtch-nm">7th Match</div></div></div></li><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-mt ...
# }</style> <meta content="400" http-equiv="refresh"/> <div class="cb-col cb-col-20"> <div class="cb-bg-white" id="cb-news-blck"><h2 class="cb-hm-lft-hdr cb-lv-scr-mtch-hdr">LATEST NEWS</h2><div class="cb-hm-lft"><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/122204/former-employee-alleges-usa-cricket-of-racial-discrimination-takes-board-to-court" title="Former contractor alleges USA Cricket of racial discrimination, takes board to court">Former contractor alleges USA Cricket of racial discrimination, takes board to court</a><div class="cb-nws-time">1h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/122199/practice-match-being-washed-out-wont-make-a-big-difference-dimuth-karunaratne-sri-lanka-cricket" title="Practice match being washed out won't make a big difference - Karunaratne">Practice match being washed out won't make a big difference - Karunaratne</a><div class="cb-nws-time">16h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/122198/domingo-apprehensive-about-playing-a-50-60-percent-fit-shakib" title="Domingo apprehensive about playing a '50-60 percent fit' Shakib">Domingo apprehensive about playing a '50-60 percent fit' Shakib</a><div class="cb-nws-time">19h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/122197/pat-cummins-ruled-out-of-ipl-2022-with-hip-injury" title="Injured Pat Cummins ruled out of IPL 2022">Injured Pat Cummins ruled out of IPL 2022</a><div class="cb-nws-time">21h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/122195/michael-bracewell-offered-maiden-nz-central-contract-james-neesham-dropped" title="Michael Bracewell offered maiden NZ central contract; James Neesham dropped">Michael Bracewell offered maiden NZ central contract; James Neesham dropped</a><div class="cb-nws-time">1d ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/122194/fleming-latches-onto-small-gains-as-curtains-come-down-on-csk" title="Fleming latches onto small gains as curtains come down on CSK">Fleming latches onto small gains as curtains come down on CSK</a><div class="cb-nws-time">1d ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/122190/uncertainty-clouds-asia-cup-australia-tour-of-sri-lanka" title="Uncertainty clouds over Asia Cup, Australia tour of Sri Lanka">Uncertainty clouds over Asia Cup, Australia tour of Sri Lanka</a><div class="cb-nws-time">1d ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/122188/brendon-mccullum-named-as-englands-test-coach" title="Brendon McCullum appointed England men's Test team head coach ">Brendon McCullum appointed England men's Test team head coach </a><div class="cb-nws-time">1d ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/122186/dont-try-too-much-donalds-advice-to-bangladesh-bowlers" title="Don't try too much - Donald's advice to Bangladesh bowlers">Don't try too much - Donald's advice to Bangladesh bowlers</a><div class="cb-nws-time">1d ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/122185/kkr-sign-up-for-uae-league-to-call-it-abu-dhabi-knight-riders" title="Knight Riders sign up for UAE league with Abu Dhabi team">Knight Riders sign up for UAE league with Abu Dhabi team</a><div class="cb-nws-time">1d ago</div></div><div class="cb-hm-mr-lnk"><a class="cb-font-12 cb-text-link" href="/cric ...
# });</script> <div class="cb-col cb-hm-mid cb-bg-white cb-hmpage" style="clear:both"> <div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>RCB VS PBKS, 60TH MATCH</span></div><a href="/live-cricket-scores/46181/rcb-vs-pbks-60th-match" title="Bairstow, Livingstone power PBKS to massive win"><img alt="Bairstow, Livingstone power PBKS to massive win" height="235" itemprop="image" src="/a/img/v1/420x235/i1/c233743/bairstow-livingstone-power-pb.jpg" title="Bairstow, Livingstone power PBKS to massive win" width="420"/></a><h2 class="big-crd-hdln"><a href="/live-cricket-scores/46181/rcb-vs-pbks-60th-match" title="Bairstow, Livingstone power PBKS to massive win">	Bairstow, Livingstone power PBKS to massive win</a></h2><div class="cb-nws-intr">Rabada bagged three wickets as PBKS secured their sixth win</div><div class="cb-hm-mtch-crd-width cb-lv-scrs-well cb-lv-scrs-well-complete"> <a href="/live-cricket-scores/46181/rcb-vs-pbks-60th-match-indian-premier-league-2022" title="RCB Vs PBKS, 60th Match Live cricket scores"> <div class="cb-col cb-col-100 cb-hm-mtch-crd cb-pos-rel"> <div class="cb-scr-wll-chvrn cb-col-90"> <div class="cb-lv-scrs-col text-black"> <div class="cb-col cb-mr-30"> <div class="text-bold">RCB</div> <div class="text-bold">PBKS</div> </div> <div class="cb-col"> <div> <span>155-9</span> <span> (20)</span> </div> <div> <span>209-9</span> <span> (20)</span> </div> </div> </div> <div class="cb-lv-scrs-col cb-text-complete" style="white-space:unset;">Punjab Kings won by 54 runs</div> </div> <div class="cb-scr-wll-chvrn cb-col-10"> <div class="cb-ico cb-lv-scr-chvrn-bg"></div> </div> </div> </a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/122203/the-wait-continues-for-kohli" title="The wait continues for Kohli">The wait continues for Kohli</a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/122202/bairstow-livingstone-keep-pbks-alive-in-playoffs-hunt" title="Bairstow, Livingstone keep PBKS alive in playoffs hunt "><span class="cb-pretag">Report / </span>Bairstow, Livingstone keep PBKS alive in playoffs hunt </a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/122206/bairstow-bosses-hazlewood-bout-to-set-up-huge-win" title="Bairstow bosses Hazlewood bout to set up huge win">Bairstow bosses Hazlewood bout to set up huge win</a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/122084/the-ipl-pulse" title="The IPL Pulse">The IPL Pulse</a></div></div><div class="sml-crd-main"><div class="crd-cntxt">INJURY UPDATE</div><div class="cb-col-33 cb-col"><a href="/cricket-news/122197/injured-pat-cummins-ruled-out-of-ipl-2022" title="Injured Pat Cummins ruled out of IPL 2022"><img alt="Injured Pat Cummins ruled out of IPL 2022" class="lazy-loading" height="75" source="/a/img/v1/135x75/i1/c233693/injured-pat-cummins-ruled-out.jpg" src="" style="padding:0px;" width="135"/></a></div><div class="cb-col-67 cb-col cb-hdln-hght"><h3 class="sml-crd-hdln"><a href="/cricket-news/122197/injured-pat-cummins-ruled-out-of-ipl-2022" title="Injured Pat Cummins ruled out of IPL 2022">Injured Pat Cummins ruled out of IPL 2022</a></h3><div class="sml-crd-subtxt">14h ago</div></div><div class="cb-nws-intr">The KKR fast bowler has left the team bubble and will complete his rehabilitation ahead of the Australia's tour of Sri Lanka</div> <div class="big-crd-reltd-itm"> <a class="big-crd-rltd-txt" href="/cricket-news/122201/embattled-kkr-srh-vie-for-redemption" title="Embattled KKR, SRH vie for redemption"><span class="cb-pretag">Preview / </span>Embattled KKR, SRH vie for redemption</a></div></div><div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>ENGLAND'S BACKROOM</span></div><a href="/cricket-news/122188/brendon-mccullum-appointed-england-mens-test-team-head-coach" title="Brendon McCullum appointed England men's Test team head coach "><img alt="Brendon McCullum ap ...

# %%
links
# Out:
# [<div class="cb-nws-intr">Rabada bagged three wickets as PBKS secured their sixth win</div>,
#  <div class="cb-nws-intr">The KKR fast bowler has left the team bubble and will complete his rehabilitation ahead of the Australia's tour of Sri Lanka</div>,
#  <div class="cb-nws-intr">The New Zealander is set to start his stint in the home series against New Zealand next month </div>,
#  <div class="cb-nws-intr">They were bowled out for just 97 by MI, who then completed the chase clinically</div>,
#  <div class="cb-nws-intr">Having emerged strong out of the mega auction, KKR now sit seventh on the points table after losing seven of their 12 games thus far. And a spot in the Playoffs feel like a long haul away. R Prasanna looks into what's going wrong for the franchise this year</div>,
#  <div class="cb-nws-intr">Left-arm spinner Ajaz Patel also returns to the 20-man shortlist for the upcoming 2022-23 season</div>,
#  <div class="cb-nws-intr">The Bangladesh allrounder had earlier been ruled out of the two-match Test series opener against Sri Lanka but is now available after testing COVID-negative</div>,
#  <div class="cb-nws-intr">Within touching distance of a Playoff finish, Rajasthan Royals need Sanju Samson to rediscover his magical touch. It's only fair in a season when his captaincy has shone through </div>,
#  <div class="cb-nws-intr">CSA can't afford to pay their players anything like an IPL salary, and push came to shove this year when many players chose to play in the tournament rather than in Tests against Bangladesh</div>,
#  <div class="cb-nws-intr">This will be the fourth team in the Knight Riders family in leagues across the world</div>,
#  <div class="cb-nws-intr">Pakistan have a packed season ahead of them, featuring at least 25 white-ball matches</div>,
#  <div class="cb-nws-intr">Bangladesh is scheduled to play two Tests, and three ODIs and T20Is each </div>,
#  <div class="cb-nws-intr">Paine has been missing in action since resigning as Australia captain on the back of an off-field scandal dating back to 2017</div>,
#  <div class="cb-nws-intr">Elsewhere, Surrey racked up 671/9 with seven players managing to go past 50</div>,
#  <div class="cb-nws-intr">In a see-saw day of legal challenges, a year-old lawsuit against the board over unconstitutional practices has been dropped</div>,
#  <div class="cb-nws-intr">CSA has dropped disciplinary charges against Mark Boucher, after losing their arbitration case against Graeme Smith last month</div>,
#  <div class="cb-nws-intr">The club has decided against offering a new contract to the former captain of the side</div>,
#  <div class="cb-nws-intr">Warner's was a career born in T20. He was "the person thrown out there", the one who legitimised it by reverse-engineering a path to Test cricket</div>,
#  <div class="cb-nws-intr">It maybe parochial to consider the fate of a cricket ball right now, but when we do count up the casualties of the ongoing war, we may have to include the Ukrainian Cricket Federation</div>,
#  <div class="cb-nws-intr">Warner's was a career born in T20. He was "the person thrown out there", the one who legitimised it by reverse-engineering a path to Test cricket</div>,
#  <div class="cb-nws-intr">In this new miniseries, we revisit how a few people influenced the Indian Premier League in everlasting fashion. First up is Chris Gayle...</div>,
#  <div class="cb-nws-intr">Back in the IPL fold after a gap of six years, the Himachal Pradesh all-rounder is now getting another chance to unlock his ambitions</div>,
#  <div class="cb-nws-intr">Venkatesh Iyer, the rising star of KKR over the past year, opens up about his very South Indian upbringing in Indore, and how Rajinikanth helped him get through the toughest of times</div>,
#  <div class="cb-nws-intr">R Prasanna looks back at his time alongside Faf du Plessis as the Proteas analyst and tells us why he could make RCB's dream come true this year</div>,
#  <div class="cb-nws-intr">Afghanistan's globe-trotting spin sensation reveals how he makes use of his different bowling grips, which one works best in Mumbai, and more in an exclusive interview</div>,
#  <div class="cb-nws-intr">As head coach of Delhi Capitals, Ricky Ponting headlines one of the most successful transitions in the IPL. He reflects on it all in an exclusive chat</div>,
#  <div class="cb-nws-intr">It's been a long tough road for Varma but the Mumbai Indians batter is now focused on making his dream come true</div>]

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# Rabada bagged three wickets as PBKS secured their sixth win
#
#
# The KKR fast bowler has left the team bubble and will complete his rehabilitation ahead of the Australia's tour of Sri Lanka
#
#
# The New Zealander is set to start his stint in the home series against New Zealand next month
#
#
# They were bowled out for just 97 by MI, who then completed the chase clinically
#
#
# Having emerged strong out of the mega auction, KKR now sit seventh on the points table after losing seven of their 12 games thus far. And a spot in the Playoffs feel like a long haul away. R Prasanna looks into what's going wrong for the franchise this year
#
#
# Left-arm spinner Ajaz Patel also returns to the 20-man shortlist for the upcoming 2022-23 season
#
#
# The Bangladesh allrounder had earlier been ruled out of the two-match Test series opener against Sri Lanka but is now available after testing COVID-negative
#
#
# Within touching distance of a Playoff finish, Rajasthan Royals need Sanju Samson to rediscover his magical touch. It's only fair in a season when his captaincy has shone through
#
#
# CSA can't afford to pay their players anything like an IPL salary, and push came to shove this year when many players chose to play in the tournament rather than in Tests against Bangladesh
#
#
# This will be the fourth team in the Knight Riders family in leagues across the world
#
#
# Pakistan have a packed season ahead of them, featuring at least 25 white-ball matches
#
#
# Bangladesh is scheduled to play two Tests, and three ODIs and T20Is each
#
#
# Paine has been missing in action since resigning as Australia captain on the back of an off-field scandal dating back to 2017
#
#
# Elsewhere, Surrey racked up 671/9 with seven players managing to go past 50
#
#
# In a see-saw day of legal challenges, a year-old lawsuit against the board over unconstitutional practices has been dropped
#
#
# CSA has dropped disciplinary charges against Mark Boucher, after losing their arbitration case against Graeme Smith last month
#
#
# The club has decided against offering a new contract to the former captain of the side
#
#
# Warner's was a career born in T20. He was "the person thrown out there", the one who legitimised it by reverse-engineering a path to Test cricket
#
#
# It maybe parochial to consider the fate of a cricket ball right now, but when we do count up the casualties of the ongoing war, we may have to include the Ukrainian Cricket Federation
#
#
# Warner's was a career born in T20. He was "the person thrown out there", the one who legitimised it by reverse-engineering a path to Test cricket
#
#
# In this new miniseries, we revisit how a few people influenced the Indian Premier League in everlasting fashion. First up is Chris Gayle...
#
#
# Back in the IPL fold after a gap of six years, the Himachal Pradesh all-rounder is now getting another chance to unlock his ambitions
#
#
# Venkatesh Iyer, the rising star of KKR over the past year, opens up about his very South Indian upbringing in Indore, and how Rajinikanth helped him get through the toughest of times
#
#
# R Prasanna looks back at his time alongside Faf du Plessis as the Proteas analyst and tells us why he could make RCB's dream come true this year
#
#
# Afghanistan's globe-trotting spin sensation reveals how he makes use of his different bowling grips, which one works best in Mumbai, and more in an exclusive interview
#
#
# As head coach of Delhi Capitals, Ricky Ponting headlines one of the most successful transitions in the IPL. He reflects on it all in an exclusive chat
#
#
# It's been a long tough road for Varma but the Mumbai Indians batter is now focused on making his dream come true

# %% [markdown]
# # Iphone

# %%
try:
        
    page=requests.get('https://www.amazon.in/Apple-iPhone-11-Pro-256GB/product-reviews/B07XVMJF2D/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews')                             # this might throw an exception if something goes wrong.
    
except Exception as e:                                   
    error_type, error_obj, error_info = sys.exc_info()     
    print ('ERROR FOR LINK:',url)                          
    print (error_type, 'Line:', error_info.tb_lineno)      
                                                 
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
linkss=soup.find_all('div',attrs={'class':'a-size-base'})

# %%
linkss
# Out:
# [<div class="a-row a-spacing-large celwidget reviews-sort-filter a-size-base" id="cm_cr-view_opt_search"><div class="a-column a-span6 a-spacing-none reviews-search-section"><div class="a-fixed-right-grid reviews-search" data-reftag="cm_cr_arp_d_viewopt_kywd"><div class="a-fixed-right-grid-inner" style="padding-right:78px"><div class="a-fixed-right-grid-col a-col-left" style="padding-right:3.5%;float:left;"><span class="a-declarative" data-action="reviews:search-textbox" data-csa-c-func-deps="aui-da-reviews:search-textbox" data-csa-c-type="widget" data-reviews:search-textbox="{}"><div class="a-search a-span12"><i class="a-icon a-icon-search"></i><input class="a-input-text a-span12" id="filterByKeywordTextBox" maxlength="300" placeholder="Search customer reviews" type="search"/></div></span></div><div class="a-fixed-right-grid-col a-col-right" style="width:78px;margin-right:-78px;float:left;"><span class="a-declarative" data-action="reviews:search-button" data-csa-c-func-deps="aui-da-reviews:search-button" data-csa-c-type="widget" data-reviews:search-button="{}"><span class="a-button a-button-search"><span class="a-button-inner"><input class="a-button-input" type="submit"><span aria-hidden="true" class="a-button-text a-text-center">Search</span></input></span></span></span></div></div></div></div></div>,
#  <div class="a-row a-spacing-small celwidget reviews-sort-filter a-size-base" id="cm_cr-view_opt_sort_filter"><div class="a-section a-spacing-mini reviews-sort-order-options aok-float-left"><div class="a-row a-spacing-small"><span class="a-size-small a-color-base reviews-sort-order-label a-text-bold a-text-caps">Sort by</span></div><div class="a-row"><span class="a-dropdown-container"><select autocomplete="off" class="a-native-dropdown a-declarative" data-action="a-dropdown-select" id="sort-order-dropdown" name="" tabindex="0"><option data-a-css-class="sort-order-option" data-reftag="cm_cr_arp_d_viewopt_srt" data-reviews-state-param='{"pageNumber":"1","sortBy":"helpful"}' value="helpful">Top reviews</option><option data-a-css-class="sort-order-option" data-reftag="cm_cr_arp_d_viewopt_srt" data-reviews-state-param='{"pageNumber":"1","sortBy":"recent"}' value="recent">Most recent</option></select><span aria-hidden="true" class="a-button a-button-dropdown cr-sort-dropdown" data-a-class="cr-sort-dropdown" tabindex="-1"><span class="a-button-inner"><span aria-hidden="true" class="a-button-text a-declarative" data-action="a-dropdown-button" data-csa-c-func-deps="aui-da-a-dropdown-button" data-csa-c-type="widget" data-csa-interaction-events="click"><span class="a-dropdown-prompt">Top reviews</span></span><i class="a-icon a-icon-dropdown"></i></span></span></span></div></div><div class="a-section a-spacing-mini reviews-filter-by-options aok-float-left"><div class="a-row a-spacing-small"><span class="a-size-small a-color-base reviews-filter-by-label a-text-bold a-text-caps">Filter by</span></div><div class="a-row reviews-filter-by-dropdown"><div class="a-column a-span3 reviewer-type-select"><span class="a-dropdown-container"><select autocomplete="off" class="a-native-dropdown a-declarative" data-action="a-dropdown-select" id="reviewer-type-dropdown" name="" tabindex="0"><option data-a-css-class="reviewer-filter-option" data-reftag="cm_cr_arp_d_viewopt_rvwer" data-reviews-state-param='{"pageNumber":"1","reviewerType":"all_reviews"}' selected="" value="all_reviews">All reviewers</option><option data-a-css-class="reviewer-filter-option" data-reftag="cm_cr_arp_d_viewopt_rvwer" data-reviews-state-param='{"pageNumber":"1","reviewerType":"avp_only_reviews"}' value="avp_only_reviews">Verified purchase only</option></select><span aria-hidden="true" class="a-button a-button-dropdown cr-filter-dropdown" data-a-class="cr-filter-dropdown" tabindex="-1"><span class="a-button-inner"><span aria-hidden="true" class="a-button-text a-declarative" data-action="a-dropdown-button" data-csa-c-func-deps="aui-da-a-dropdown-button" data-csa-c-type="widget" data-csa-interaction-events="click"><span class="a-dropdown-prompt">All reviewers</span></span><i class="a-icon a-icon-dropdown"></i></span></span></span></div><div class="a-column a-span3 star-rating-select"><span class="a-dropdown-container"><select autocomplete="off" class="a-native-dropdown a-declarative" data-action="a-dropdown-select" id="star-count-dropdown" name="" tabindex="0"><optgroup><option data-a-css-class="star-filter-option" data-reftag="cm_cr_arp_d_viewopt_sr" data-reviews-state-param='{"pageNumber":"1","filterByStar":"all_stars"}' value="all_stars">All stars</option><option data-a-css-class="star-filter-option" data-reftag="cm_cr_arp_d_viewopt_sr" data-reviews-state-param='{"pageNumber":"1","filterByStar":"five_star"}' value="five_star">5 star only</option><option data-a-css-class="star-filter-option" data-reftag="cm_cr_arp_d_viewopt_sr" data-reviews-state-param='{"pageNumber":"1","filterByStar":"four_star"}' value="four_star">4 star only</option><option data-a-css-class="star-filter-option" data-reftag="cm_cr_arp_d_viewopt_sr" data-reviews-state-param='{"pageNumber":"1","filterByStar":"three_star"}' value="three_star">3 star only</option><option data-a-css-class="star-filter-option" data-reftag="cm_cr_arp_d_viewopt_sr" data-reviews-state-param='{"pageNumber":"1","filterByStar":"two_star"}'  ...
#  <div class="a-row a-spacing-base a-size-base" data-hook="cr-filter-info-review-rating-count">
#  <span>
#                      1,340 global ratings | 354 global reviews
#                  </span>
#  </div>,
#  <div class="a-section a-spacing-none reviews-content a-size-base"><div class="a-section cr-list-loading reviews-loading aok-hidden"></div><div class="a-section a-spacing-top-large a-text-center review-filter-error aok-hidden"><div class="a-box a-alert a-alert-error cr-error" role="alert"><div class="a-box-inner a-alert-container"><h4 class="a-alert-heading">There was a problem filtering reviews right now. Please try again later.</h4><i class="a-icon a-icon-alert"></i><div class="a-alert-content"></div></div></div></div><div class="a-section a-spacing-none reviews-content a-size-base"><div class="a-section a-spacing-none review-views celwidget" id="cm_cr-review_list"><h3 class="a-spacing-medium" data-hook="arp-local-reviews-header">
#
#
#
#
#
#
#
#
#  From India
#  </h3><div class="a-section review aok-relative" data-hook="review" id="R27V2V9SQOX9PI"><div class="a-row a-spacing-none" id="R27V2V9SQOX9PI-review-card"><div class="a-section celwidget" id="customer_review-R27V2V9SQOX9PI"><div class="a-row a-spacing-mini" data-hook="genome-widget"><a class="a-profile" data-a-size="small" href="/gp/profile/amzn1.account.AFJ5ZAAXAGPFPJQSHANNED34V3ZQ"><div aria-hidden="true" class="a-profile-avatar-wrapper"><div class="a-profile-avatar"><img class="a-lazy-loaded" data-src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/6b9e3094-0a92-48b3-ad17-c395f6f6fcd2._CR0,0,375,375_SX48_.jpg" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif"/><noscript><img src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/6b9e3094-0a92-48b3-ad17-c395f6f6fcd2._CR0,0,375,375_SX48_.jpg"/></noscript></div></div><div class="a-profile-content"><span class="a-profile-name">Soumyajit Dey</span></div></a></div><div class="a-row"><a class="a-link-normal" href="/gp/customer-reviews/R27V2V9SQOX9PI?ASIN=B07XVMJF2D" title="5.0 out of 5 stars"><i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i></a><span class="a-letter-space"></span><a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R27V2V9SQOX9PI?ASIN=B07XVMJF2D">
#  <span>BEST PHONE in the SmartPhone Market..........Hands'Down</span>
#  </a></div><span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 16 September 2019</span><div class="a-row a-spacing-mini review-data review-format-strip"></div><div class="a-row a-spacing-small review-data"><span class="a-size-base review-text review-text-content" data-hook="review-body">
#  <span>You Have to Love APPLE because they not only make amazing product they make Magic ....... I loved specially the Ultrawide Angle camera and the Hell of a Beast of a Processor .... A13Bionic , I am an Engineer and the way Apple Presented the Chip on the stage blew my mind ...... that small piece of hardware has 8.5 Billion transistor and based on 7NM architecture ...... simple word its like a Lamborgini and other Chips are Honda ! Finally this is gonna be the beast of a phone and another thing that made me happy Apple might manufacture and assemble these phones in India itself! Kudos Apple You did an Amazing work! Your the Best!</span>
#  </span></div><div class="a-popover-preload" id="a-popover-R27V2V9SQOX9PI_gallerySection_main">
#  <div class="a-section cr-lightbox-popover-container" data-hook="image-popover" id="R27V2V9SQOX9PI_image_popover">
#  <div class="cr-lightbox-image-viewer">
#  <div class="cr-lightbox-main-image-container">
#  <img alt="Customer image" class="cr-lightbox-main-image" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/transparent-pixel._V192234675_.gif"/>
#  </div>
#  <div class="cr-lightbox-navigator-container cr-lightbox-navigator-container__back">
#  <div class="cr-lightbox-navigator-button cr-lightbox-navigator-button__back">
#  </div>
#  </div>
#  <div class="cr-lightbox-navigator-container cr-lightbox-navigator-container__next">
#  <div class="cr-lightbox-navigator-button cr-lightbox-navigator-button__next">
#  </div>
#  </div>
#  </div>
#  <div class="a-section cr-lightbox-review-information">
#  <div class="a-section a-spacing-mini cr-review-stars-and-title">
#  <div class="a-row a-spacing-mini">
#  <a class="a-profile cr-lightbox-customer-profile" data-a-size="small" href="/gp/profile/amzn1.account.AFJ5ZAAXAGPFPJQSHANNED34V3ZQ"><div aria-hidden="true" class="a-profile-avatar-wrapper"><div class="a-profile-avatar"><img class="a-lazy-loaded" data-src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/6b9e3094-0a92-48b3-ad17-c395f6f6fcd2._CR0,0,375,375_SX48_.jpg" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif"/><noscript><img src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/6b9e3094-0a92-48b3-ad17-c395f6f6fcd2._CR0,0,375,375_SX48_.jpg"/></noscript></div></div><div class="a-profile-content"><span class="a-profile-name">Soumyajit Dey</span></div></a>
#  </div>
#  <i class="a-icon a-icon-star a-star-5 cr-lightbox-review-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i>
#  <span class="a-size-base cr-lightbox-review-title a-text-bold">
#                  BEST PHONE in the SmartPhone Market..........Hands'Down
#              </span>
#  <br/>
#  <span class="a-size-small a-color-secondary cr-lightbox-review-origin">
#
#
#
#
#
#
#
#                                      Reviewed in India on 16 September 2019
#
#
#
#
#
#              </span>
#  </div>
#  <span class="a-size-base cr-lightbox-review-body">
#              You Have to Love APPLE because they not only make amazing product they make Magic ....... I loved specially the Ultrawide Angle camera and the Hell of a Beast of a Processor .... A13Bionic , I am an Engineer and the way Apple Presented the Chip on the stage blew my mind ...... that small piece of hardware has 8.5 Billion transistor and based on 7NM architecture ...... simple word its like a Lamborgini and other Chips are Honda ! Finally this is gonna be the beast of a phone and another thing that made me happy Apple might manufacture and assemble these phones in India itself! Kudos Apple You did an Amazing work! Your the Best!
#          </span>
#  <div class="a-section a-spacing-top-base">
#  <span class="a-size-medium a-color-secondary">
#                  Images in this review
#              </span>
#  <div class="a-section a-spacing-top-mini cr-lightbox-image-thumbnails">
#  <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://images-na.ssl-images-amazon.com/images/I/61j2DpQJBKL._SY88.jpg"/>
#  <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://images-na.ssl-images-amazon.com/images/I/61kMzPJyW3L._SY88.jpg"/>
#  <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://images-na.ssl-images-amazon.com/images/I/71oWReGwDiL._SY88.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>
#  <script>
#     function toggleSeeAllView() {
#         P.when('A', 'cr-image-popover-controller').execute(function(A, imagePopoverController) {
#            imagePopoverController.toggleSeeAllView(true);
#         });
#     }
#  </script>
#  </div><div class="a-section a-spacing-medium review-image-container" id="R27V2V9SQOX9PI_imageSection_main"><div class="review-image-tile-section" data-reviewid="R27V2V9SQOX9PI">
#  <span class="a-declarative" data-a-modal='{"name":"R27V2V9SQOX9PI_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R27V2V9SQOX9PI-0"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://images-na.ssl-images-amazon.com/images/I/61j2DpQJBKL._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span><span class="a-declarative" data-a-modal='{"name":"R27V2V9SQOX9PI_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R27V2V9SQOX9PI-1"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://images-na.ssl-images-amazon.com/images/I/61kMzPJyW3L._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span><span class="a-declarative" data-a-modal='{"name":"R27V2V9SQOX9PI_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R27V2V9SQOX9PI-2"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://images-na.ssl-images-amazon.com/images/I/71oWReGwDiL._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span></div>
#  </div><script>
#          P.when('A', 'cr-image-popover-controller').execute(function(A, imagePopoverController) {
#            A.on("a:popover:beforeShow:R27V2V9SQOX9PI_gallerySection_main", function(data) {
#              imagePopoverController.initImagePopover("R27V2V9SQOX9PI", "[https://images-na.ssl-images-amazon.com/images/I/61j2DpQJBKL.jpg, https://images-na.ssl-images-amazon.com/images/I/61kMzPJyW3L.jpg, https://images-na.ssl-images-amazon.com/images/I/71oWReGwDiL.jpg]", data);
#            });
#          });
#      </script>
#  <div class="a-row review-comments comments-for-R27V2V9SQOX9PI"><div class="a-row a-expander-container a-expander-inline-container cr-vote-action-bar" data-a-expander-name="review_comment_expander" data-reftag="cm_cr_arp_d_cmt_opn"><span class="cr-vote" data-hook="review-voting-widget">
#  <div class="a-row a-spacing-small"><span class="a-size-base a-color-tertiary cr-vote-text" data-hook="helpful-vote-statement">914 people found this helpful</span></div><div class="cr-helpful-button aok-float-left">
#  <span class="a-button a-button-base"><span class="a-button-inner"><a class="a-button-text" data-hook="vote-helpful-button" href="https://www.amazon.in/ap/signin?openid.return_to=https%3A%2F%2Fwww.amazon.in%2FApple-iPhone-11-Pro-256GB%2Fproduct-reviews%2FB07XVMJF2D%3FreviewerType%3Dall_reviews%26csrfT%3Dg8UgdopmdfS3ezmVfqaGfVp0Kn2LQCo6v7GJDVDyBMqFAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%252B4jBkd8T3F%252BolA%253D%253D%26reviewId%3DR27V2V9SQOX9PI&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.assoc_handle=inflex&amp;openid.mode=checkid_setup&amp;marketPlaceId=A21TJRUUN4KGV&amp;language=en&amp;openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0"><div class="cr-helpful-text">
#            Helpful</div>
#  </a></span></span></div>
#  </span><span class="cr-footer-line-height">
#  <span><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><span class="a-declarative" data-action="cr-popup" data-cr-popup='{"width":"580","title":"ReportAbuse","url":"/hz/reviews-render/report-review?ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=g8UgdopmdfS3ezmVfqaGfVp0Kn2LQCo6v7GJDVDyBMqFAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%2B4jBkd8T3F%2BolA%3D%3D&amp;reviewId=R27V2V9SQOX9PI","height":"380"}' data-csa-c-func-deps="aui-da-cr-popup" data-csa-c-type="widget"><a class="a-size-base a-link-normal a-color-secondary report-abuse-link a-text-normal" href="/hz/reviews-render/report-review?ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=g8UgdopmdfS3ezmVfqaGfVp0Kn2LQCo6v7GJDVDyBMqFAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%2B4jBkd8T3F%2BolA%3D%3D&amp;reviewId=R27V2V9SQOX9PI">Report abuse</a></span></span></span>
#  <div aria-expanded="false" class="a-expander-content a-spacing-top-base a-spacing-large a-expander-inline-content a-expander-inner" style="display:none"><div class="a-row a-spacing-mini review-comments-header aok-hidden"><ul class="a-viewoptions-list a-viewoptions-section a-span12">
#  <div class="a-row a-spacing-none a-grid-vertical-align a-grid-center"><div class="a-column a-span6"><span class="a-size-base a-viewoptions-list-label">Showing <span class="review-comment-count">0</span> comments</span></div></div></ul>
#  </div><div class="a-section a-spacing-extra-large a-spacing-top-medium a-text-center comment-load-error aok-hidden"><div class="a-box a-alert a-alert-error cr-error" role="alert"><div class="a-box-inner a-alert-container"><h4 class="a-alert-heading">There was a problem loading comments right now. Please try again later.</h4><i class="a-icon a-icon-alert"></i><div class="a-alert-content"></div></div></div></div><div class="a-section a-spacing-none review-comments"></div><div class="a-spinner-wrapper comment-loading aok-hidden a-spacing-top-medium a-spacing-extra-large"><span class="a-spinner a-spinner-medium"></span></div><hr aria-hidden="true" class="a-spacing-none a-spacing-top-large a-divider-normal"/></div></div></div></div></div></div><div class="a-section review aok-relative" data-hook="review" id="R3VHYYEE4ID5AZ"><div class="a-row a-spacing-none" id="R3VHYYEE4ID5AZ-review-card"><div class="a-section celwidget" id="customer_review-R3VHYYEE4ID5AZ"><div class="a-row a-spacing-mini" data-hook="genome-widget"><a class="a-profile" data-a-size="small" data-a-verified="true" href="/gp/profile/amzn1.account.AGSVVSM5AMVWJSROZ3LR4C266QVQ"><div aria-hidden="true" class="a-profile-avatar-wrapper"><div class="a-profile-avatar"><img class="a-lazy-loaded" data-src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/d5783e3d-16fd-4b35-acd8-c889a4beb9b0._CR0,0,400,400_SX48_.jpg" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif"/><noscript><img src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/d5783e3d-16fd-4b35-acd8-c889a4beb9b0._CR0,0,400,400_SX48_.jpg"/></noscript></div></div><div class="a-profile-content"><span class="a-profile-name">VXI<span class="a-profile-verified-badge"><span class="a-profile-verified-text"></span></span></span></div></a></div><div class="a-row"><a class="a-link-normal" href="/gp/customer-reviews/R3VHYYEE4ID5AZ?ASIN=B07XVMJF2D" title="5.0 out of 5 stars"><i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i></a><span class="a-letter-space"></span><a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R3VHYYEE4ID5AZ?ASIN=B07XVMJF2D">
#  <span>Nice and low price</span>
#  </a></div><span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 19 September 2019</span><div class="a-row a-spacing-mini review-data review-format-strip"></div><div class="a-row a-spacing-small review-data"><span class="a-size-base review-text review-text-content" data-hook="review-body">
#  <span>You Have to Love APPLE because they not only make amazing product they make Magic ....... I loved specially the Ultrawide Angle camera and the Hell of a Beast of a Processor .... A13Bionic , I am an Engineer and the way Apple Presented the Chip on the stage blew my mind ...... that small piece of hardware has 8.5 Billion transistor and based on 7NM architecture ...... simple word its like a Lamborgini and other Chips are Honda ! Finally this is gonna be the beast of a phone and another thing that made me happy Apple might manufacture and assemble these phones in India itself! Kudos Apple You did an Amazing work! Your the Best!</span>
#  </span></div><div class="a-row review-comments comments-for-R3VHYYEE4ID5AZ"><div class="a-row a-expander-container a-expander-inline-container cr-vote-action-bar" data-a-expander-name="review_comment_expander" data-reftag="cm_cr_arp_d_cmt_opn"><span class="cr-vote" data-hook="review-voting-widget">
#  <div class="a-row a-spacing-small"><span class="a-size-base a-color-tertiary cr-vote-text" data-hook="helpful-vote-statement">486 people found this helpful</span></div><div class="cr-helpful-button aok-float-left">
#  <span class="a-button a-button-base"><span class="a-button-inner"><a class="a-button-text" data-hook="vote-helpful-button" href="https://www.amazon.in/ap/signin?openid.return_to=https%3A%2F%2Fwww.amazon.in%2FApple-iPhone-11-Pro-256GB%2Fproduct-reviews%2FB07XVMJF2D%3FreviewerType%3Dall_reviews%26csrfT%3Dgx2kWmuBmvseN9Rpd6mlSXiTum3%252BB8lWKqutQ7i4%252F0iyAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%252B4jBkd8T3F%252BolA%253D%253D%26reviewId%3DR3VHYYEE4ID5AZ&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.assoc_handle=inflex&amp;openid.mode=checkid_setup&amp;marketPlaceId=A21TJRUUN4KGV&amp;language=en&amp;openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0"><div class="cr-helpful-text">
#            Helpful</div>
#  </a></span></span></div>
#  </span><span class="cr-footer-line-height">
#  <span><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><span class="a-declarative" data-action="cr-popup" data-cr-popup='{"width":"580","title":"ReportAbuse","url":"/hz/reviews-render/report-review?ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=gx2kWmuBmvseN9Rpd6mlSXiTum3%2BB8lWKqutQ7i4%2F0iyAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%2B4jBkd8T3F%2BolA%3D%3D&amp;reviewId=R3VHYYEE4ID5AZ","height":"380"}' data-csa-c-func-deps="aui-da-cr-popup" data-csa-c-type="widget"><a class="a-size-base a-link-normal a-color-secondary report-abuse-link a-text-normal" href="/hz/reviews-render/report-review?ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=gx2kWmuBmvseN9Rpd6mlSXiTum3%2BB8lWKqutQ7i4%2F0iyAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%2B4jBkd8T3F%2BolA%3D%3D&amp;reviewId=R3VHYYEE4ID5AZ">Report abuse</a></span></span></span>
#  <div aria-expanded="false" class="a-expander-content a-spacing-top-base a-spacing-large a-expander-inline-content a-expander-inner" style="display:none"><div class="a-row a-spacing-mini review-comments-header aok-hidden"><ul class="a-viewoptions-list a-viewoptions-section a-span12">
#  <div class="a-row a-spacing-none a-grid-vertical-align a-grid-center"><div class="a-column a-span6"><span class="a-size-base a-viewoptions-list-label">Showing <span class="review-comment-count">0</span> comments</span></div></div></ul>
#  </div><div class="a-section a-spacing-extra-large a-spacing-top-medium a-text-center comment-load-error aok-hidden"><div class="a-box a-alert a-alert-error cr-error" role="alert"><div class="a-box-inner a-alert-container"><h4 class="a-alert-heading">There was a problem loading comments right now. Please try again later.</h4><i class="a-icon a-icon-alert"></i><div class="a-alert-content"></div></div></div></div><div class="a-section a-spacing-none review-comments"></div><div class="a-spinner-wrapper comment-loading aok-hidden a-spacing-top-medium a-spacing-extra-large"><span class="a-spinner a-spinner-medium"></span></div><hr aria-hidden="true" class="a-spacing-none a-spacing-top-large a-divider-normal"/></div></div></div></div></div></div><div class="a-section review aok-relative" data-hook="review" id="R3L47S7I79XUBX"><div class="a-row a-spacing-none" id="R3L47S7I79XUBX-review-card"><div class="a-section celwidget" id="customer_review-R3L47S7I79XUBX"><div class="a-row a-spacing-mini" data-hook="genome-widget"><a class="a-profile" data-a-size="small" href="/gp/profile/amzn1.account.AEHB7FTDYAEFL2HVLFMDQZ5RXSYQ"><div aria-hidden="true" class="a-profile-avatar-wrapper"><div class="a-profile-avatar"><img class="a-lazy-loaded" data-src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif"/><noscript><img src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png"/></noscript></div></div><div class="a-profile-content"><span class="a-profile-name">Ekanta</span></div></a></div><div class="a-row"><a class="a-link-normal" href="/gp/customer-reviews/R3L47S7I79XUBX?ASIN=B07XVMJF2D" title="4.0 out of 5 stars"><i class="a-icon a-icon-star a-star-4 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">4.0 out of 5 stars</span></i></a><span class="a-letter-space"></span><a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R3L47S7I79XUBX?ASIN=B07XVMJF2D">
#  <span>Camera</span>
#  </a></div><span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 29 September 2019</span><div class="a-row a-spacing-mini review-data review-format-strip"><span class="a-declarative" data-action="reviews:filter-action:push-state" data-csa-c-func-deps="aui-da-reviews:filter-action:push-state" data-csa-c-type="widget" data-reviews:filter-action:push-state="{}"><a class="a-link-normal" data-reftag="cm_cr_arp_d_rvw_rvwer" data-reviews-state-param='{"pageNumber":"1","reviewerType":"avp_only_reviews"}' href="/Apple-iPhone-11-Pro-256GB/product-reviews/B07XVMJF2D?reviewerType=avp_only_reviews"><span class="a-size-mini a-color-state a-text-bold" data-hook="avp-badge">Verified Purchase</span></a></span></div><div class="a-row a-spacing-small review-data"><span class="a-size-base review-text review-text-content" data-hook="review-body">
#  <span>I just got today. This looks really sexy. Awesome Camera, display. Thanks apple.</span>
#  </span></div><div class="a-row review-comments comments-for-R3L47S7I79XUBX"><div class="a-row a-expander-container a-expander-inline-container cr-vote-action-bar" data-a-expander-name="review_comment_expander" data-reftag="cm_cr_arp_d_cmt_opn"><span class="cr-vote" data-hook="review-voting-widget">
#  <div class="a-row a-spacing-small"><span class="a-size-base a-color-tertiary cr-vote-text" data-hook="helpful-vote-statement">242 people found this helpful</span></div><div class="cr-helpful-button aok-float-left">
#  <span class="a-button a-button-base"><span class="a-button-inner"><a class="a-button-text" data-hook="vote-helpful-button" href="https://www.amazon.in/ap/signin?openid.return_to=https%3A%2F%2Fwww.amazon.in%2FApple-iPhone-11-Pro-256GB%2Fproduct-reviews%2FB07XVMJF2D%3FreviewerType%3Dall_reviews%26csrfT%3DgyzBhOpaTKGWcbv2kGq4Q%252BW7XpS0ktBncR0nwgtP8vKhAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%252B4jBkd8T3F%252BolA%253D%253D%26reviewId%3DR3L47S7I79XUBX&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.assoc_handle=inflex&amp;openid.mode=checkid_setup&amp;marketPlaceId=A21TJRUUN4KGV&amp;language=en&amp;openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0"><div class="cr-helpful-text">
#            Helpful</div>
#  </a></span></span></div>
#  </span><span class="cr-footer-line-height">
#  <span><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><span class="a-declarative" data-action="cr-popup" data-cr-popup='{"width":"580","title":"ReportAbuse","url":"/hz/reviews-render/report-review?ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=gyzBhOpaTKGWcbv2kGq4Q%2BW7XpS0ktBncR0nwgtP8vKhAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%2B4jBkd8T3F%2BolA%3D%3D&amp;reviewId=R3L47S7I79XUBX","height":"380"}' data-csa-c-func-deps="aui-da-cr-popup" data-csa-c-type="widget"><a class="a-size-base a-link-normal a-color-secondary report-abuse-link a-text-normal" href="/hz/reviews-render/report-review?ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=gyzBhOpaTKGWcbv2kGq4Q%2BW7XpS0ktBncR0nwgtP8vKhAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%2B4jBkd8T3F%2BolA%3D%3D&amp;reviewId=R3L47S7I79XUBX">Report abuse</a></span></span></span>
#  <div aria-expanded="false" class="a-expander-content a-spacing-top-base a-spacing-large a-expander-inline-content a-expander-inner" style="display:none"><div class="a-row a-spacing-mini review-comments-header aok-hidden"><ul class="a-viewoptions-list a-viewoptions-section a-span12">
#  <div class="a-row a-spacing-none a-grid-vertical-align a-grid-center"><div class="a-column a-span6"><span class="a-size-base a-viewoptions-list-label">Showing <span class="review-comment-count">0</span> comments</span></div></div></ul>
#  </div><div class="a-section a-spacing-extra-large a-spacing-top-medium a-text-center comment-load-error aok-hidden"><div class="a-box a-alert a-alert-error cr-error" role="alert"><div class="a-box-inner a-alert-container"><h4 class="a-alert-heading">There was a problem loading comments right now. Please try again later.</h4><i class="a-icon a-icon-alert"></i><div class="a-alert-content"></div></div></div></div><div class="a-section a-spacing-none review-comments"></div><div class="a-spinner-wrapper comment-loading aok-hidden a-spacing-top-medium a-spacing-extra-large"><span class="a-spinner a-spinner-medium"></span></div><hr aria-hidden="true" class="a-spacing-none a-spacing-top-large a-divider-normal"/></div></div></div></div></div></div><div class="a-section review aok-relative" data-hook="review" id="R1G7NW63ZDFEOP"><div class="a-row a-spacing-none" id="R1G7NW63ZDFEOP-review-card"><div class="a-section celwidget" id="customer_review-R1G7NW63ZDFEOP"><div class="a-row a-spacing-mini" data-hook="genome-widget"><a class="a-profile" data-a-size="small" href="/gp/profile/amzn1.account.AFT5VLD2GYENMCR5XHR2N7MAHKKQ"><div aria-hidden="true" class="a-profile-avatar-wrapper"><div class="a-profile-avatar"><img class="a-lazy-loaded" data-src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/ad8bd53e-8365-4687-8adb-4cea8541e1e9._CR0,0,375,375_SX48_.jpg" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif"/><noscript><img src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/ad8bd53e-8365-4687-8adb-4cea8541e1e9._CR0,0,375,375_SX48_.jpg"/></noscript></div></div><div class="a-profile-content"><span class="a-profile-name">Aradhya.inc</span></div></a></div><div class="a-row"><a class="a-link-normal" href="/gp/customer-reviews/R1G7NW63ZDFEOP?ASIN=B07XVMJF2D" title="3.0 out of 5 stars"><i class="a-icon a-icon-star a-star-3 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">3.0 out of 5 stars</span></i></a><span class="a-letter-space"></span><a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R1G7NW63ZDFEOP?ASIN=B07XVMJF2D">
#  <span>Upto the Mark but not too much change &amp; Battery Blunder</span>
#  </a></div><span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 4 October 2019</span><div class="a-row a-spacing-mini review-data review-format-strip"><span class="a-declarative" data-action="reviews:filter-action:push-state" data-csa-c-func-deps="aui-da-reviews:filter-action:push-state" data-csa-c-type="widget" data-reviews:filter-action:push-state="{}"><a class="a-link-normal" data-reftag="cm_cr_arp_d_rvw_rvwer" data-reviews-state-param='{"pageNumber":"1","reviewerType":"avp_only_reviews"}' href="/Apple-iPhone-11-Pro-256GB/product-reviews/B07XVMJF2D?reviewerType=avp_only_reviews"><span class="a-size-mini a-color-state a-text-bold" data-hook="avp-badge">Verified Purchase</span></a></span></div><div class="a-row a-spacing-small review-data"><span class="a-size-base review-text review-text-content" data-hook="review-body">
#  <span>I am always being fan of iOS &amp; Apple Products.<br>Reason:-<br/>Quality<br/>Performance<br/>Transparent Customer Support<br/>Design<br/>Build Quality<br/>Updates<br/>Sound Quality<br/>Promises too.<br/>Going to write review post a week usage.<br/>Pros.<br/>Display Quality<br/>Performance<br/>Speed<br/>Fast charging<br/>Camera<br/>Even Selfie camera Quality enhanced<br/>Triple camera also good as described.<br/>New Color Midnight Green added as a charm.<br/>E-Sim<br/>IP68 better than others.<br/>Battery Usage too better then iPhone XS.<br/>Durability too.<br/><br/>Cons.<br/>No 3D Touch.<br/>Old Headphones no changes<br/>In india its too much expensive<br/>Heating issue<br/>While charging please don’t use it bcz thereafter you can fry an egg on it 😂.<br/>Low Screen Refresh Rate.<br/>Just 10-20% better than iPhone XS.<br/>Camera fails in lighting, ma be apple sort-out this in next update.<br/><br/>I am giving :-<br/>Screen 4/5<br/>Design 5/5<br/>Performance 4/5 (Heating)<br/>Sound 5/5<br/>Price 3/5 (too much expensive)<br/>Customer Support 5/5<br/>Now battery life falls to 84% in Just 400 Charges.<br/>Amazon Delivery 3/5 (i am not satisfied bcz they not delivered the product as per promise.<br/><br/>Soon i’ll publish the pics shoots on iPhone 11 Pro.<br/><br/>Thanks for Reading.</br></span>
#  </span></div><div class="a-popover-preload" id="a-popover-R1G7NW63ZDFEOP_gallerySection_main">
#  <div class="a-section cr-lightbox-popover-container" data-hook="image-popover" id="R1G7NW63ZDFEOP_image_popover">
#  <div class="cr-lightbox-image-viewer">
#  <div class="cr-lightbox-main-image-container">
#  <img alt="Customer image" class="cr-lightbox-main-image" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/transparent-pixel._V192234675_.gif"/>
#  </div>
#  <div class="cr-lightbox-navigator-container cr-lightbox-navigator-container__back">
#  <div class="cr-lightbox-navigator-button cr-lightbox-navigator-button__back">
#  </div>
#  </div>
#  <div class="cr-lightbox-navigator-container cr-lightbox-navigator-container__next">
#  <div class="cr-lightbox-navigator-button cr-lightbox-navigator-button__next">
#  </div>
#  </div>
#  </div>
#  <div class="a-section cr-lightbox-review-information">
#  <div class="a-section a-spacing-mini cr-review-stars-and-title">
#  <div class="a-row a-spacing-mini">
#  <a class="a-profile cr-lightbox-customer-profile" data-a-size="small" href="/gp/profile/amzn1.account.AFT5VLD2GYENMCR5XHR2N7MAHKKQ"><div aria-hidden="true" class="a-profile-avatar-wrapper"><div class="a-profile-avatar"><img class="a-lazy-loaded" data-src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/ad8bd53e-8365-4687-8adb-4cea8541e1e9._CR0,0,375,375_SX48_.jpg" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif"/><noscript><img src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/ad8bd53e-8365-4687-8adb-4cea8541e1e9._CR0,0,375,375_SX48_.jpg"/></noscript></div></div><div class="a-profile-content"><span class="a-profile-name">Aradhya.inc</span></div></a>
#  </div>
#  <i class="a-icon a-icon-star a-star-3 cr-lightbox-review-rating"><span class="a-icon-alt">3.0 out of 5 stars</span></i>
#  <span class="a-size-base cr-lightbox-review-title a-text-bold">
#                  Upto the Mark but not too much change &amp; Battery Blunder
#              </span>
#  <br/>
#  <span class="a-size-small a-color-secondary cr-lightbox-review-origin">
#
#
#
#
#
#
#
#                                      Reviewed in India on 4 October 2019
#
#
#
#
#
#              </span>
#  </div>
#  <span class="a-size-base cr-lightbox-review-body">
#              I am always being fan of iOS &amp; Apple Products.<br>Reason:-<br/>Quality<br/>Performance<br/>Transparent Customer Support<br/>Design<br/>Build Quality<br/>Updates<br/>Sound Quality<br/>Promises too.<br/>Going to write review post a week usage.<br/>Pros.<br/>Display Quality<br/>Performance<br/>Speed<br/>Fast charging<br/>Camera<br/>Even Selfie camera Quality enhanced<br/>Triple camera also good as described.<br/>New Color Midnight Green added as a charm.<br/>E-Sim<br/>IP68 better than others.<br/>Battery Usage too better then iPhone XS.<br/>Durability too.<br/><br/>Cons.<br/>No 3D Touch.<br/>Old Headphones no changes<br/>In india its too much expensive<br/>Heating issue<br/>While charging please don’t use it bcz thereafter you can fry an egg on it 😂.<br/>Low Screen Refresh Rate.<br/>Just 10-20% better than iPhone XS.<br/>Camera fails in lighting, ma be apple sort-out this in next update.<br/><br/>I am giving :-<br/>Screen 4/5<br/>Design 5/5<br/>Performance 4/5 (Heating)<br/>Sound 5/5<br/>Price 3/5 (too much expensive)<br/>Customer Support 5/5<br/>Now battery life falls to 84% in Just 400 Charges.<br/>Amazon Delivery 3/5 (i am not satisfied bcz they not delivered the product as per promise.<br/><br/>Soon i’ll publish the pics shoots on iPhone 11 Pro.<br/><br/>Thanks for Reading.
#          </br></span>
#  <div class="a-section a-spacing-top-base">
#  <span class="a-size-medium a-color-secondary">
#                  Images in this review
#              </span>
#  <div class="a-section a-spacing-top-mini cr-lightbox-image-thumbnails">
#  <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://images-na.ssl-images-amazon.com/images/I/61KxWDRCDQL._SY88.jpg"/>
#  <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://images-na.ssl-images-amazon.com/images/I/61iOaw2jJRL._SY88.jpg"/>
#  <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://images-na.ssl-images-amazon.com/images/I/71I6MBHzAdL._SY88.jpg"/>
#  <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://images-na.ssl-images-amazon.com/images/I/71Zf-ZObO0L._SY88.jpg"/>
#  <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://images-na.ssl-images-amazon.com/images/I/71nCT8HZ45L._SY88.jpg"/>
#  <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://images-na.ssl-images-amazon.com/images/I/71phus9XB2L._SY88.jpg"/>
#  <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://images-na.ssl-images-amazon.com/images/I/81Eww1dHchL._SY88.jpg"/>
#  <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://images-na.ssl-images-amazon.com/images/I/81IyP5lMfYL._SY88.jpg"/>
#  <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://images-na.ssl-images-amazon.com/images/I/81qxwIRrRkL._SY88.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>
#  <script>
#     function toggleSeeAllView() {
#         P.when('A', 'cr-image-popover-controller').execute(function(A, imagePopoverController) {
#            imagePopoverController.toggleSeeAllView(true);
#         });
#     }
#  </script>
#  </div><div class="a-section a-spacing-medium review-image-container" id="R1G7NW63ZDFEOP_imageSection_main"><div class="review-image-tile-section" data-reviewid="R1G7NW63ZDFEOP">
#  <span class="a-declarative" data-a-modal='{"name":"R1G7NW63ZDFEOP_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R1G7NW63ZDFEOP-0"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://images-na.ssl-images-amazon.com/images/I/61KxWDRCDQL._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span><span class="a-declarative" data-a-modal='{"name":"R1G7NW63ZDFEOP_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R1G7NW63ZDFEOP-1"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://images-na.ssl-images-amazon.com/images/I/61iOaw2jJRL._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span><span class="a-declarative" data-a-modal='{"name":"R1G7NW63ZDFEOP_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R1G7NW63ZDFEOP-2"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://images-na.ssl-images-amazon.com/images/I/71I6MBHzAdL._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span><span class="a-declarative" data-a-modal='{"name":"R1G7NW63ZDFEOP_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R1G7NW63ZDFEOP-3"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://images-na.ssl-images-amazon.com/images/I/71Zf-ZObO0L._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span><span class="a-declarative" data-a-modal='{"name":"R1G7NW63ZDFEOP_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R1G7NW63ZDFEOP-4"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://images-na.ssl-images-amazon.com/images/I/71nCT8HZ45L._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span><span class="a-declarative" data-a-modal='{"name":"R1G7NW63ZDFEOP_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R1G7NW63ZDFEOP-5"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://images-na.ssl-images-amazon.com/images/I/71phus9XB2L._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span><span class="a-declarative" data-a-modal='{"name":"R1G7NW63ZDFEOP_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R1G7NW63ZDFEOP-6"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://images-na.ssl-images-amazon.com/images/I/81Eww1dHchL._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span><span class="a-declarative" data-a-modal='{"name":"R1G7NW63ZDFEOP_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R1G7NW63ZDFEOP-7"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://images-na.ssl-images-amazon.c ...
#  </div><script>
#          P.when('A', 'cr-image-popover-controller').execute(function(A, imagePopoverController) {
#            A.on("a:popover:beforeShow:R1G7NW63ZDFEOP_gallerySection_main", function(data) {
#              imagePopoverController.initImagePopover("R1G7NW63ZDFEOP", "[https://images-na.ssl-images-amazon.com/images/I/61KxWDRCDQL.jpg, https://images-na.ssl-images-amazon.com/images/I/61iOaw2jJRL._SL1600_.jpg, https://images-na.ssl-images-amazon.com/images/I/71I6MBHzAdL._SL1600_.jpg, https://images-na.ssl-images-amazon.com/images/I/71Zf-ZObO0L._SL1600_.jpg, https://images-na.ssl-images-amazon.com/images/I/71nCT8HZ45L._SL1600_.jpg, https://images-na.ssl-images-amazon.com/images/I/71phus9XB2L._SL1600_.jpg, https://images-na.ssl-images-amazon.com/images/I/81Eww1dHchL._SL1600_.jpg, https://images-na.ssl-images-amazon.com/images/I/81IyP5lMfYL._SL1600_.jpg, https://images-na.ssl-images-amazon.com/images/I/81qxwIRrRkL._SL1600_.jpg]", data);
#            });
#          });
#      </script>
#  <div class="a-row review-comments comments-for-R1G7NW63ZDFEOP"><div class="a-row a-expander-container a-expander-inline-container cr-vote-action-bar" data-a-expander-name="review_comment_expander" data-reftag="cm_cr_arp_d_cmt_opn"><span class="cr-vote" data-hook="review-voting-widget">
#  <div class="a-row a-spacing-small"><span class="a-size-base a-color-tertiary cr-vote-text" data-hook="helpful-vote-statement">251 people found this helpful</span></div><div class="cr-helpful-button aok-float-left">
#  <span class="a-button a-button-base"><span class="a-button-inner"><a class="a-button-text" data-hook="vote-helpful-button" href="https://www.amazon.in/ap/signin?openid.return_to=https%3A%2F%2Fwww.amazon.in%2FApple-iPhone-11-Pro-256GB%2Fproduct-reviews%2FB07XVMJF2D%3FreviewerType%3Dall_reviews%26csrfT%3DgyV877J40JEtWRcPSoH8bDQxrbXKGLmOzuYvoR16g%252FRfAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%252B4jBkd8T3F%252BolA%253D%253D%26reviewId%3DR1G7NW63ZDFEOP&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.assoc_handle=inflex&amp;openid.mode=checkid_setup&amp;marketPlaceId=A21TJRUUN4KGV&amp;language=en&amp;openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0"><div class="cr-helpful-text">
#            Helpful</div>
#  </a></span></span></div>
#  </span><span class="cr-footer-line-height">
#  <span><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><span class="a-declarative" data-action="cr-popup" data-cr-popup='{"width":"580","title":"ReportAbuse","url":"/hz/reviews-render/report-review?ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=gyV877J40JEtWRcPSoH8bDQxrbXKGLmOzuYvoR16g%2FRfAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%2B4jBkd8T3F%2BolA%3D%3D&amp;reviewId=R1G7NW63ZDFEOP","height":"380"}' data-csa-c-func-deps="aui-da-cr-popup" data-csa-c-type="widget"><a class="a-size-base a-link-normal a-color-secondary report-abuse-link a-text-normal" href="/hz/reviews-render/report-review?ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=gyV877J40JEtWRcPSoH8bDQxrbXKGLmOzuYvoR16g%2FRfAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%2B4jBkd8T3F%2BolA%3D%3D&amp;reviewId=R1G7NW63ZDFEOP">Report abuse</a></span></span></span>
#  <div aria-expanded="false" class="a-expander-content a-spacing-top-base a-spacing-large a-expander-inline-content a-expander-inner" style="display:none"><div class="a-row a-spacing-mini review-comments-header aok-hidden"><ul class="a-viewoptions-list a-viewoptions-section a-span12">
# ...
#  <div class="cr-lightbox-image-viewer">
#  <div class="cr-lightbox-main-image-container">
#  <img alt="Customer image" class="cr-lightbox-main-image" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/transparent-pixel._V192234675_.gif"/>
#  </div>
#  <div class="cr-lightbox-navigator-container cr-lightbox-navigator-container__back">
#  <div class="cr-lightbox-navigator-button cr-lightbox-navigator-button__back">
#  </div>
#  </div>
#  <div class="cr-lightbox-navigator-container cr-lightbox-navigator-container__next">
#  <div class="cr-lightbox-navigator-button cr-lightbox-navigator-button__next">
#  </div>
#  </div>
#  </div>
#  <div class="a-section cr-lightbox-review-information">
#  <div class="a-section a-spacing-mini cr-review-stars-and-title">
#  <div class="a-row a-spacing-mini">
#  <a class="a-profile cr-lightbox-customer-profile" data-a-size="small" href="/gp/profile/amzn1.account.AGROBTGAI6UELG7E6PRGZ4YNET2A"><div aria-hidden="true" class="a-profile-avatar-wrapper"><div class="a-profile-avatar"><img class="a-lazy-loaded" data-src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif"/><noscript><img src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png"/></noscript></div></div><div class="a-profile-content"><span class="a-profile-name">ashish kumar</span></div></a>
#  </div>
#  <i class="a-icon a-icon-star a-star-4 cr-lightbox-review-rating"><span class="a-icon-alt">4.0 out of 5 stars</span></i>
#  <span class="a-size-base cr-lightbox-review-title a-text-bold">
#                  Good phone with super camara
#              </span>
#  <br/>
#  <span class="a-size-small a-color-secondary cr-lightbox-review-origin">
#
#
#
#
#
#
#
#                                      Reviewed in India on 12 October 2019
#
#
#
#
#
#              </span>
#  </div>
#  <span class="a-size-base cr-lightbox-review-body">
#              Excellent camera, and nothing else is new, and obviously the processor and speed is good.
#          </span>
#  <div class="a-section a-spacing-top-base">
#  <span class="a-size-medium a-color-secondary">
#                  Images in this review
#              </span>
#  <div class="a-section a-spacing-top-mini cr-lightbox-image-thumbnails">
#  <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://images-na.ssl-images-amazon.com/images/I/61gSjAIBCTL._SY88.jpg"/>
#  <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://images-na.ssl-images-amazon.com/images/I/716SDkGrthL._SY88.jpg"/>
#  <img alt="Customer image" class="cr-lightbox-image-thumbnail" src="https://images-na.ssl-images-amazon.com/images/I/71ozhiyYWIL._SY88.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>
#  <script>
#     function toggleSeeAllView() {
#         P.when('A', 'cr-image-popover-controller').execute(function(A, imagePopoverController) {
#            imagePopoverController.toggleSeeAllView(true);
#         });
#     }
#  </script>
#  </div><div class="a-section a-spacing-medium review-image-container" id="R3P0CJLPGIDNS2_imageSection_main"><div class="review-image-tile-section" data-reviewid="R3P0CJLPGIDNS2">
#  <span class="a-declarative" data-a-modal='{"name":"R3P0CJLPGIDNS2_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R3P0CJLPGIDNS2-0"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://images-na.ssl-images-amazon.com/images/I/61gSjAIBCTL._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span><span class="a-declarative" data-a-modal='{"name":"R3P0CJLPGIDNS2_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R3P0CJLPGIDNS2-1"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://images-na.ssl-images-amazon.com/images/I/716SDkGrthL._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span><span class="a-declarative" data-a-modal='{"name":"R3P0CJLPGIDNS2_gallerySection_main"}' data-action="a-modal" data-csa-c-func-deps="aui-da-a-modal" data-csa-c-type="widget" id="R3P0CJLPGIDNS2-2"><a class="a-popover-trigger a-declarative" href="javascript:void(0)" role="button"><img alt="Customer image" class="review-image-tile" data-hook="review-image-tile" height="88" src="https://images-na.ssl-images-amazon.com/images/I/71ozhiyYWIL._SY88.jpg" width="100%"/><i class="a-icon a-icon-popover"></i></a></span></div>
#  </div><script>
#          P.when('A', 'cr-image-popover-controller').execute(function(A, imagePopoverController) {
#            A.on("a:popover:beforeShow:R3P0CJLPGIDNS2_gallerySection_main", function(data) {
#              imagePopoverController.initImagePopover("R3P0CJLPGIDNS2", "[https://images-na.ssl-images-amazon.com/images/I/61gSjAIBCTL.jpg, https://images-na.ssl-images-amazon.com/images/I/716SDkGrthL.jpg, https://images-na.ssl-images-amazon.com/images/I/71ozhiyYWIL.jpg]", data);
#            });
#          });
#      </script>
#  <div class="a-row review-comments comments-for-R3P0CJLPGIDNS2"><div class="a-row a-expander-container a-expander-inline-container cr-vote-action-bar" data-a-expander-name="review_comment_expander" data-reftag="cm_cr_arp_d_cmt_opn"><span class="cr-vote" data-hook="review-voting-widget">
#  <div class="a-row a-spacing-small"><span class="a-size-base a-color-tertiary cr-vote-text" data-hook="helpful-vote-statement">61 people found this helpful</span></div><div class="cr-helpful-button aok-float-left">
#  <span class="a-button a-button-base"><span class="a-button-inner"><a class="a-button-text" data-hook="vote-helpful-button" href="https://www.amazon.in/ap/signin?openid.return_to=https%3A%2F%2Fwww.amazon.in%2FApple-iPhone-11-Pro-256GB%2Fproduct-reviews%2FB07XVMJF2D%3FreviewerType%3Dall_reviews%26csrfT%3Dg0Z9uJqmorhDIXzI76BTN3yS57uuKYWHNwkDPHJM1vwXAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%252B4jBkd8T3F%252BolA%253D%253D%26reviewId%3DR3P0CJLPGIDNS2&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.assoc_handle=inflex&amp;openid.mode=checkid_setup&amp;marketPlaceId=A21TJRUUN4KGV&amp;language=en&amp;openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0"><div class="cr-helpful-text">
#            Helpful</div>
#  </a></span></span></div>
#  </span><span class="cr-footer-line-height">
#  <span><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><span class="a-declarative" data-action="cr-popup" data-cr-popup='{"width":"580","title":"ReportAbuse","url":"/hz/reviews-render/report-review?ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=g0Z9uJqmorhDIXzI76BTN3yS57uuKYWHNwkDPHJM1vwXAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%2B4jBkd8T3F%2BolA%3D%3D&amp;reviewId=R3P0CJLPGIDNS2","height":"380"}' data-csa-c-func-deps="aui-da-cr-popup" data-csa-c-type="widget"><a class="a-size-base a-link-normal a-color-secondary report-abuse-link a-text-normal" href="/hz/reviews-render/report-review?ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=g0Z9uJqmorhDIXzI76BTN3yS57uuKYWHNwkDPHJM1vwXAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%2B4jBkd8T3F%2BolA%3D%3D&amp;reviewId=R3P0CJLPGIDNS2">Report abuse</a></span></span></span>
#  <div aria-expanded="false" class="a-expander-content a-spacing-top-base a-spacing-large a-expander-inline-content a-expander-inner" style="display:none"><div class="a-row a-spacing-mini review-comments-header aok-hidden"><ul class="a-viewoptions-list a-viewoptions-section a-span12">
#  <div class="a-row a-spacing-none a-grid-vertical-align a-grid-center"><div class="a-column a-span6"><span class="a-size-base a-viewoptions-list-label">Showing <span class="review-comment-count">0</span> comments</span></div></div></ul>
#  </div><div class="a-section a-spacing-extra-large a-spacing-top-medium a-text-center comment-load-error aok-hidden"><div class="a-box a-alert a-alert-error cr-error" role="alert"><div class="a-box-inner a-alert-container"><h4 class="a-alert-heading">There was a problem loading comments right now. Please try again later.</h4><i class="a-icon a-icon-alert"></i><div class="a-alert-content"></div></div></div></div><div class="a-section a-spacing-none review-comments"></div><div class="a-spinner-wrapper comment-loading aok-hidden a-spacing-top-medium a-spacing-extra-large"><span class="a-spinner a-spinner-medium"></span></div><hr aria-hidden="true" class="a-spacing-none a-spacing-top-large a-divider-normal"/></div></div></div></div></div></div><div class="a-section review aok-relative" data-hook="review" id="R2NB0JXE4HEBXS"><div class="a-row a-spacing-none" id="R2NB0JXE4HEBXS-review-card"><div class="a-section celwidget" id="customer_review-R2NB0JXE4HEBXS"><div class="a-row a-spacing-mini" data-hook="genome-widget"><a class="a-profile" data-a-size="small" href="/gp/profile/amzn1.account.AGPJUVBZ6CUDEIUKZIL4Y7EZARRQ"><div aria-hidden="true" class="a-profile-avatar-wrapper"><div class="a-profile-avatar"><img class="a-lazy-loaded" data-src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif"/><noscript><img src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png"/></noscript></div></div><div class="a-profile-content"><span class="a-profile-name">Harishwar</span></div></a></div><div class="a-row"><a class="a-link-normal" href="/gp/customer-reviews/R2NB0JXE4HEBXS?ASIN=B07XVMJF2D" title="1.0 out of 5 stars"><i class="a-icon a-icon-star a-star-1 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">1.0 out of 5 stars</span></i></a><span class="a-letter-space"></span><a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R2NB0JXE4HEBXS?ASIN=B07XVMJF2D">
#  <span>Not worth</span>
#  </a></div><span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 25 December 2019</span><div class="a-row a-spacing-mini review-data review-format-strip"><span class="a-declarative" data-action="reviews:filter-action:push-state" data-csa-c-func-deps="aui-da-reviews:filter-action:push-state" data-csa-c-type="widget" data-reviews:filter-action:push-state="{}"><a class="a-link-normal" data-reftag="cm_cr_arp_d_rvw_rvwer" data-reviews-state-param='{"pageNumber":"1","reviewerType":"avp_only_reviews"}' href="/Apple-iPhone-11-Pro-256GB/product-reviews/B07XVMJF2D?reviewerType=avp_only_reviews"><span class="a-size-mini a-color-state a-text-bold" data-hook="avp-badge">Verified Purchase</span></a></span></div><div class="a-row a-spacing-small review-data"><span class="a-size-base review-text review-text-content" data-hook="review-body">
#  <span>If it charged 100% phone getting unlocking problems...... iam nt understanding its only for my mobile r for all iphones??????? Return policy given only 2weeks wat if any problem find out in week 3 ???????</span>
#  </span></div><div class="a-row review-comments comments-for-R2NB0JXE4HEBXS"><div class="a-row a-expander-container a-expander-inline-container cr-vote-action-bar" data-a-expander-name="review_comment_expander" data-reftag="cm_cr_arp_d_cmt_opn"><span class="cr-vote" data-hook="review-voting-widget">
#  <div class="a-row a-spacing-small"><span class="a-size-base a-color-tertiary cr-vote-text" data-hook="helpful-vote-statement">39 people found this helpful</span></div><div class="cr-helpful-button aok-float-left">
#  <span class="a-button a-button-base"><span class="a-button-inner"><a class="a-button-text" data-hook="vote-helpful-button" href="https://www.amazon.in/ap/signin?openid.return_to=https%3A%2F%2Fwww.amazon.in%2FApple-iPhone-11-Pro-256GB%2Fproduct-reviews%2FB07XVMJF2D%3FreviewerType%3Dall_reviews%26csrfT%3Dg15PX9BtxZBJoT5S54CQr94F3TfagIHpGYQga44htcCwAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%252B4jBkd8T3F%252BolA%253D%253D%26reviewId%3DR2NB0JXE4HEBXS&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.assoc_handle=inflex&amp;openid.mode=checkid_setup&amp;marketPlaceId=A21TJRUUN4KGV&amp;language=en&amp;openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&amp;openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0"><div class="cr-helpful-text">
#            Helpful</div>
#  </a></span></span></div>
#  </span><span class="cr-footer-line-height">
#  <span><i aria-label="|" class="a-icon a-icon-text-separator" role="img"></i><span class="a-declarative" data-action="cr-popup" data-cr-popup='{"width":"580","title":"ReportAbuse","url":"/hz/reviews-render/report-review?ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=g15PX9BtxZBJoT5S54CQr94F3TfagIHpGYQga44htcCwAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%2B4jBkd8T3F%2BolA%3D%3D&amp;reviewId=R2NB0JXE4HEBXS","height":"380"}' data-csa-c-func-deps="aui-da-cr-popup" data-csa-c-type="widget"><a class="a-size-base a-link-normal a-color-secondary report-abuse-link a-text-normal" href="/hz/reviews-render/report-review?ref=cm_cr_arp_d_rvw_hlp&amp;csrfT=g15PX9BtxZBJoT5S54CQr94F3TfagIHpGYQga44htcCwAAAAAQAAAABifzMBcmF3AAAAAPuJFBJP%2B4jBkd8T3F%2BolA%3D%3D&amp;reviewId=R2NB0JXE4HEBXS">Report abuse</a></span></span></span>
#  <div aria-expanded="false" class="a-expander-content a-spacing-top-base a-spacing-large a-expander-inline-content a-expander-inner" style="display:none"><div class="a-row a-spacing-mini review-comments-header aok-hidden"><ul class="a-viewoptions-list a-viewoptions-section a-span12">
#  <div class="a-row a-spacing-none a-grid-vertical-align a-grid-center"><div class="a-column a-span6"><span class="a-size-base a-viewoptions-list-label">Showing <span class="review-comment-count">0</span> comments</span></div></div></ul>
#  </div><div class="a-section a-spacing-extra-large a-spacing-top-medium a-text-center comment-load-error aok-hidden"><div class="a-box a-alert a-alert-error cr-error" role="alert"><div class="a-box-inner a-alert-container"><h4 class="a-alert-heading">There was a problem loading comments right now. Please try again later.</h4><i class="a-icon a-icon-alert"></i><div class="a-alert-content"></div></div></div></div><div class="a-section a-spacing-none review-comments"></div><div class="a-spinner-wrapper comment-loading aok-hidden a-spacing-top-medium a-spacing-extra-large"><span class="a-spinner a-spinner-medium"></span></div><hr aria-hidden="true" class="a-spacing-none a-spacing-top-large a-divider-normal"/></div></div></div></div></div></div><div class="a-form-actions a-spacing-top-extra-large"><span class="a-declarative" data-action="reviews:page-action" data-csa-c-func-deps="aui-da-reviews:page-action" data-csa-c-type="widget" data-reviews:page-action='{"allowLinkDefault":"1"}'><div class="a-text-center celwidget a-text-base" data-hook="pagination-bar" data-reftag="cm_cr_arp_d_paging_btm" id="cm_cr-pagination_bar" role="navigation"><ul class="a-pagination"><li class="a-disabled">←<span class="a-letter-space"></span><span class="a-letter-space"></span>Previous page</li><li class="a-last"><a href="/Apple-iPhone-11-Pro-256GB/product-reviews/B07XVMJF2D?pageNumber=2&amp;reviewerType=all_reviews">Next page<span class="a-letter-space"></span><span class="a-letter-space"></span>→</a></li></ul></div></span></div></div></div>]

# %%
for i in linkss:
    print(i.text)
    print("\n")
# Out:
# Search
#
#
# Sort byTop reviewsMost recentTop reviewsFilter byAll reviewersVerified purchase onlyAll reviewersAll stars5 star only4 star only3 star only2 star only1 star onlyAll positiveAll criticalAll starsAll text, image and video reviewsImage and video reviews onlyAll text, image and video reviews
#
#
#
#
#                     1,340 global ratings | 354 global reviews
#
#
#
#
# There was a problem filtering reviews right now. Please try again later.
#
#
#
#
#
#
#
#
# From India
# Soumyajit Dey5.0 out of 5 stars
# BEST PHONE in the SmartPhone Market..........Hands'Down
# Reviewed in India on 16 September 2019
# You Have to Love APPLE because they not only make amazing product they make Magic ....... I loved specially the Ultrawide Angle camera and the Hell of a Beast of a Processor .... A13Bionic , I am an Engineer and the way Apple Presented the Chip on the stage blew my mind ...... that small piece of hardware has 8.5 Billion transistor and based on 7NM architecture ...... simple word its like a Lamborgini and other Chips are Honda ! Finally this is gonna be the beast of a phone and another thing that made me happy Apple might manufacture and assemble these phones in India itself! Kudos Apple You did an Amazing work! Your the Best!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Soumyajit Dey
#
# 5.0 out of 5 stars
#
#                 BEST PHONE in the SmartPhone Market..........Hands'Down
#
#
#
#
#
#
#
#
#
#
#                                     Reviewed in India on 16 September 2019
#
#
#
#
#
#
#
#
#             You Have to Love APPLE because they not only make amazing product they make Magic ....... I loved specially the Ultrawide Angle camera and the Hell of a Beast of a Processor .... A13Bionic , I am an Engineer and the way Apple Presented the Chip on the stage blew my mind ...... that small piece of hardware has 8.5 Billion transistor and based on 7NM architecture ...... simple word its like a Lamborgini and other Chips are Honda ! Finally this is gonna be the beast of a phone and another thing that made me happy Apple might manufacture and assemble these phones in India itself! Kudos Apple You did an Amazing work! Your the Best!
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 914 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.VXI5.0 out of 5 stars
# Nice and low price
# Reviewed in India on 19 September 2019
# You Have to Love APPLE because they not only make amazing product they make Magic ....... I loved specially the Ultrawide Angle camera and the Hell of a Beast of a Processor .... A13Bionic , I am an Engineer and the way Apple Presented the Chip on the stage blew my mind ...... that small piece of hardware has 8.5 Billion transistor and based on 7NM architecture ...... simple word its like a Lamborgini and other Chips are Honda ! Finally this is gonna be the beast of a phone and another thing that made me happy Apple might manufacture and assemble these phones in India itself! Kudos Apple You did an Amazing work! Your the Best!
#
# 486 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Ekanta4.0 out of 5 stars
# Camera
# Reviewed in India on 29 September 2019Verified Purchase
# I just got today. This looks really sexy. Awesome Camera, display. Thanks apple.
#
# 242 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Aradhya.inc3.0 out of 5 stars
# Upto the Mark but not too much change & Battery Blunder
# Reviewed in India on 4 October 2019Verified Purchase
# I am always being fan of iOS & Apple Products.Reason:-QualityPerformanceTransparent Customer SupportDesignBuild QualityUpdatesSound QualityPromises too.Going to write review post a week usage.Pros.Display QualityPerformanceSpeedFast chargingCameraEven Selfie camera Quality enhancedTriple camera also good as described.New Color Midnight Green added as a charm.E-SimIP68 better than others.Battery Usage too better then iPhone XS.Durability too.Cons.No 3D Touch.Old Headphones no changesIn india its too much expensiveHeating issueWhile charging please don’t use it bcz thereafter you can fry an egg on it 😂.Low Screen Refresh Rate.Just 10-20% better than iPhone XS.Camera fails in lighting, ma be apple sort-out this in next update.I am giving :-Screen 4/5Design 5/5Performance 4/5 (Heating)Sound 5/5Price 3/5 (too much expensive)Customer Support 5/5Now battery life falls to 84% in Just 400 Charges.Amazon Delivery 3/5 (i am not satisfied bcz they not delivered the product as per promise.Soon i’ll publish the pics shoots on iPhone 11 Pro.Thanks for Reading.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aradhya.inc
#
# 3.0 out of 5 stars
#
#                 Upto the Mark but not too much change & Battery Blunder
#
#
#
#
#
#
#
#
#
#
#                                     Reviewed in India on 4 October 2019
#
#
#
#
#
#
#
#
#             I am always being fan of iOS & Apple Products.Reason:-QualityPerformanceTransparent Customer SupportDesignBuild QualityUpdatesSound QualityPromises too.Going to write review post a week usage.Pros.Display QualityPerformanceSpeedFast chargingCameraEven Selfie camera Quality enhancedTriple camera also good as described.New Color Midnight Green added as a charm.E-SimIP68 better than others.Battery Usage too better then iPhone XS.Durability too.Cons.No 3D Touch.Old Headphones no changesIn india its too much expensiveHeating issueWhile charging please don’t use it bcz thereafter you can fry an egg on it 😂.Low Screen Refresh Rate.Just 10-20% better than iPhone XS.Camera fails in lighting, ma be apple sort-out this in next update.I am giving :-Screen 4/5Design 5/5Performance 4/5 (Heating)Sound 5/5Price 3/5 (too much expensive)Customer Support 5/5Now battery life falls to 84% in Just 400 Charges.Amazon Delivery 3/5 (i am not satisfied bcz they not delivered the product as per promise.Soon i’ll publish the pics shoots on iPhone 11 Pro.Thanks for Reading.
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 251 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Shubham Upadhyay1.0 out of 5 stars
# Worst product
# Reviewed in India on 9 December 2019Verified Purchase
# This is the worst product... it's getting heatup to much ...I am requested Amazon to replace it then they didn't help me out...m very disappointed..
#
# 66 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Deepak1.0 out of 5 stars
# bad
# Reviewed in India on 6 October 2019Verified Purchase
# box is open
#
# 85 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Shramana Mukherjee1.0 out of 5 stars
# I'm too rich for this.
# Reviewed in India on 10 November 2019
# So cheap!I don't like cheap things!
#
# 115 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Yashwant Anil Shirodkar1.0 out of 5 stars
# Automatically getting restart & keeps getting hang
# Reviewed in India on 28 October 2019Verified Purchase
# Phone restarted on its own. Customer support is of no use. I end up having defective phone after spending close to 1 lakh
#
# 69 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.ashish kumar4.0 out of 5 stars
# Good phone with super camara
# Reviewed in India on 12 October 2019Verified Purchase
# Excellent camera, and nothing else is new, and obviously the processor and speed is good.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ashish kumar
#
# 4.0 out of 5 stars
#
#                 Good phone with super camara
#
#
#
#
#
#
#
#
#
#
#                                     Reviewed in India on 12 October 2019
#
#
#
#
#
#
#
#
#             Excellent camera, and nothing else is new, and obviously the processor and speed is good.
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 61 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Harishwar1.0 out of 5 stars
# Not worth
# Reviewed in India on 25 December 2019Verified Purchase
# If it charged 100% phone getting unlocking problems...... iam nt understanding its only for my mobile r for all iphones??????? Return policy given only 2weeks wat if any problem find out in week 3 ???????
#
# 39 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.←Previous pageNext page→
#
#
#
#
#
#
#
#
#
#
#
# From India
# Soumyajit Dey5.0 out of 5 stars
# BEST PHONE in the SmartPhone Market..........Hands'Down
# Reviewed in India on 16 September 2019
# You Have to Love APPLE because they not only make amazing product they make Magic ....... I loved specially the Ultrawide Angle camera and the Hell of a Beast of a Processor .... A13Bionic , I am an Engineer and the way Apple Presented the Chip on the stage blew my mind ...... that small piece of hardware has 8.5 Billion transistor and based on 7NM architecture ...... simple word its like a Lamborgini and other Chips are Honda ! Finally this is gonna be the beast of a phone and another thing that made me happy Apple might manufacture and assemble these phones in India itself! Kudos Apple You did an Amazing work! Your the Best!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Soumyajit Dey
#
# 5.0 out of 5 stars
#
#                 BEST PHONE in the SmartPhone Market..........Hands'Down
#
#
#
#
#
#
#
#
#
#
#                                     Reviewed in India on 16 September 2019
#
#
#
#
#
#
#
#
#             You Have to Love APPLE because they not only make amazing product they make Magic ....... I loved specially the Ultrawide Angle camera and the Hell of a Beast of a Processor .... A13Bionic , I am an Engineer and the way Apple Presented the Chip on the stage blew my mind ...... that small piece of hardware has 8.5 Billion transistor and based on 7NM architecture ...... simple word its like a Lamborgini and other Chips are Honda ! Finally this is gonna be the beast of a phone and another thing that made me happy Apple might manufacture and assemble these phones in India itself! Kudos Apple You did an Amazing work! Your the Best!
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 914 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.VXI5.0 out of 5 stars
# Nice and low price
# Reviewed in India on 19 September 2019
# You Have to Love APPLE because they not only make amazing product they make Magic ....... I loved specially the Ultrawide Angle camera and the Hell of a Beast of a Processor .... A13Bionic , I am an Engineer and the way Apple Presented the Chip on the stage blew my mind ...... that small piece of hardware has 8.5 Billion transistor and based on 7NM architecture ...... simple word its like a Lamborgini and other Chips are Honda ! Finally this is gonna be the beast of a phone and another thing that made me happy Apple might manufacture and assemble these phones in India itself! Kudos Apple You did an Amazing work! Your the Best!
#
# 486 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Ekanta4.0 out of 5 stars
# Camera
# Reviewed in India on 29 September 2019Verified Purchase
# I just got today. This looks really sexy. Awesome Camera, display. Thanks apple.
#
# 242 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Aradhya.inc3.0 out of 5 stars
# Upto the Mark but not too much change & Battery Blunder
# Reviewed in India on 4 October 2019Verified Purchase
# I am always being fan of iOS & Apple Products.Reason:-QualityPerformanceTransparent Customer SupportDesignBuild QualityUpdatesSound QualityPromises too.Going to write review post a week usage.Pros.Display QualityPerformanceSpeedFast chargingCameraEven Selfie camera Quality enhancedTriple camera also good as described.New Color Midnight Green added as a charm.E-SimIP68 better than others.Battery Usage too better then iPhone XS.Durability too.Cons.No 3D Touch.Old Headphones no changesIn india its too much expensiveHeating issueWhile charging please don’t use it bcz thereafter you can fry an egg on it 😂.Low Screen Refresh Rate.Just 10-20% better than iPhone XS.Camera fails in lighting, ma be apple sort-out this in next update.I am giving :-Screen 4/5Design 5/5Performance 4/5 (Heating)Sound 5/5Price 3/5 (too much expensive)Customer Support 5/5Now battery life falls to 84% in Just 400 Charges.Amazon Delivery 3/5 (i am not satisfied bcz they not delivered the product as per promise.Soon i’ll publish the pics shoots on iPhone 11 Pro.Thanks for Reading.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aradhya.inc
#
# 3.0 out of 5 stars
#
#                 Upto the Mark but not too much change & Battery Blunder
#
#
#
#
#
#
#
#
#
#
#                                     Reviewed in India on 4 October 2019
#
#
#
#
#
#
#
#
#             I am always being fan of iOS & Apple Products.Reason:-QualityPerformanceTransparent Customer SupportDesignBuild QualityUpdatesSound QualityPromises too.Going to write review post a week usage.Pros.Display QualityPerformanceSpeedFast chargingCameraEven Selfie camera Quality enhancedTriple camera also good as described.New Color Midnight Green added as a charm.E-SimIP68 better than others.Battery Usage too better then iPhone XS.Durability too.Cons.No 3D Touch.Old Headphones no changesIn india its too much expensiveHeating issueWhile charging please don’t use it bcz thereafter you can fry an egg on it 😂.Low Screen Refresh Rate.Just 10-20% better than iPhone XS.Camera fails in lighting, ma be apple sort-out this in next update.I am giving :-Screen 4/5Design 5/5Performance 4/5 (Heating)Sound 5/5Price 3/5 (too much expensive)Customer Support 5/5Now battery life falls to 84% in Just 400 Charges.Amazon Delivery 3/5 (i am not satisfied bcz they not delivered the product as per promise.Soon i’ll publish the pics shoots on iPhone 11 Pro.Thanks for Reading.
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 251 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Shubham Upadhyay1.0 out of 5 stars
# Worst product
# Reviewed in India on 9 December 2019Verified Purchase
# This is the worst product... it's getting heatup to much ...I am requested Amazon to replace it then they didn't help me out...m very disappointed..
#
# 66 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Deepak1.0 out of 5 stars
# bad
# Reviewed in India on 6 October 2019Verified Purchase
# box is open
#
# 85 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Shramana Mukherjee1.0 out of 5 stars
# I'm too rich for this.
# Reviewed in India on 10 November 2019
# So cheap!I don't like cheap things!
#
# 115 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Yashwant Anil Shirodkar1.0 out of 5 stars
# Automatically getting restart & keeps getting hang
# Reviewed in India on 28 October 2019Verified Purchase
# Phone restarted on its own. Customer support is of no use. I end up having defective phone after spending close to 1 lakh
#
# 69 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.ashish kumar4.0 out of 5 stars
# Good phone with super camara
# Reviewed in India on 12 October 2019Verified Purchase
# Excellent camera, and nothing else is new, and obviously the processor and speed is good.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ashish kumar
#
# 4.0 out of 5 stars
#
#                 Good phone with super camara
#
#
#
#
#
#
#
#
#
#
#                                     Reviewed in India on 12 October 2019
#
#
#
#
#
#
#
#
#             Excellent camera, and nothing else is new, and obviously the processor and speed is good.
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 61 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Harishwar1.0 out of 5 stars
# Not worth
# Reviewed in India on 25 December 2019Verified Purchase
# If it charged 100% phone getting unlocking problems...... iam nt understanding its only for my mobile r for all iphones??????? Return policy given only 2weeks wat if any problem find out in week 3 ???????
#
# 39 people found this helpful
#
#           Helpful
#
#
# Report abuse
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.←Previous pageNext page→
